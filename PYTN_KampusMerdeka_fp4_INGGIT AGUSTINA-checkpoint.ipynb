# %% [markdown]
# # Project Final 4

# %% [markdown]
# # Clustering

# %% [markdown]
# Import the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load data Credit Card

# %%
df = pd.read_csv('CC GENERAL.csv')

# %% [markdown]
# Data Info

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# Data check

# %%
print(df.head())
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# Cek statistik deskriptif data numerik

# %%
print(df.describe())
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# Memeriksa jumlah nilai yang hilang pada setiap kolom

# %%
print("\nJumlah nilai yang hilang:")
print(df.isnull().sum())
# Out:
# Jumlah nilai yang hilang:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# Objective yang ingin dicapai :
# Mengidentifikasi pola atau kelompok : Clustering bertujuan untuk mengelompokkan data ke dalam kelompok-kelompok yang memiliki pola atau karakteristik serupa.
#
# Memahami profil atau karakteristik kelompok: Clustering membantu dalam memahami karakteristik dan profil dari setiap kelompok. Objective dalam hal ini adalah untuk mengidentifikasi perbedaan dan kesamaan antara kelompok-kelompok tersebut dalam hal atribut atau fitur yang relevan.
#
# Evaluasi model: Objective dalam hal ini adalah untuk mengevaluasi kualitas dan konsistensi hasil clustering.
#
# Pengambilan keputusan: Clustering dapat membantu dalam pengambilan keputusan dengan mengidentifikasi kelompok yang serupa.

# %% [markdown]
# Memeriksa korelasi antara fitur numerik

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Korelasi antara Fitur Numerik')
plt.show()

# %% [markdown]
# Memeriksa distribusi fitur numerik

# %%
numeric_features = ['BALANCE', 'PURCHASES', 'CASH_ADVANCE', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS']
df_numeric = df[numeric_features]
df_numeric.hist(bins=30, figsize=(15, 10))
plt.suptitle('Distribusi Fitur Numerik')
plt.show()

# %% [markdown]
# # Explorasi Data Analisis

# %% [markdown]
# # Query dan Grouping

# %% [markdown]
# Import the required libraries

# %%
import pandas as pd

# %% [markdown]
# Load data

# %%
data = pd.read_csv('CC GENERAL.csv')

# %% [markdown]
# Grouping data

# %% [markdown]
# Misalnya, menghitung rata-rata purchases berdasarkan credit limit

# %%
grouped_df = df.groupby('CREDIT_LIMIT')['PURCHASES'].mean()
print("\nData yang telah digrouping:")
print(grouped_df)
# Out:
# Data yang telah digrouping:
# CREDIT_LIMIT
# 50.0           0.000000
# 150.0         45.800000
# 200.0         81.813333
# 300.0        405.390000
# 400.0        644.826667
#                ...
# 22500.0    49039.570000
# 23000.0    11435.000000
# 25000.0     1471.550000
# 28000.0    26582.340000
# 30000.0    15677.135000
# Name: PURCHASES, Length: 205, dtype: float64

# %% [markdown]
# Deskripsi dari hasil grouping tersebut adalah sebagai berikut:
#
# Data yang telah digrouping berdasarkan variabel "CREDIT_LIMIT" dengan nilai-nilai kategori sebagai berikut:
#
# Kategori 50.0: Jumlah pembelian (PURCHASES) adalah 0.0.
# Kategori 150.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 45.8.
# Kategori 200.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 81.81.
# Kategori 300.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 405.39.
# Kategori 400.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 644.83.
# ...
# Kategori 22500.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 49039.57.
# Kategori 23000.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 11435.0.
# Kategori 25000.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 1471.55.
# Kategori 28000.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 26582.34.
# Kategori 30000.0: Rata-rata jumlah pembelian (PURCHASES) sekitar 15677.13.
#
# Data ini memberikan informasi tentang pengelompokan nilai-nilai variabel "PURCHASES" berdasarkan kategori "CREDIT_LIMIT". Setiap kategori menunjukkan rentang nilai kredit yang berbeda, dan untuk setiap kategori, rata-rata jumlah pembelian (PURCHASES) telah dihitung.

# %% [markdown]
# # Central Tendency

# %% [markdown]
# Import the required libraries

# %%
import pandas as pd

# %% [markdown]
# Load data

# %%
df = pd.read_csv('CC GENERAL.csv')

# %% [markdown]
# Selects a numeric column

# %%
numeric_columns = data.select_dtypes(include='number')

# %% [markdown]
# Calculates the mean (average) of a numeric column

# %%
mean_values = numeric_columns.mean()
print("Mean (Rata-rata) Values:")
print(mean_values)
# Out:
# Mean (Rata-rata) Values:
# BALANCE                             1564.474828
# BALANCE_FREQUENCY                      0.877271
# PURCHASES                           1003.204834
# ONEOFF_PURCHASES                     592.437371
# INSTALLMENTS_PURCHASES               411.067645
# CASH_ADVANCE                         978.871112
# PURCHASES_FREQUENCY                    0.490351
# ONEOFF_PURCHASES_FREQUENCY             0.202458
# PURCHASES_INSTALLMENTS_FREQUENCY       0.364437
# CASH_ADVANCE_FREQUENCY                 0.135144
# CASH_ADVANCE_TRX                       3.248827
# PURCHASES_TRX                         14.709832
# CREDIT_LIMIT                        4494.449450
# PAYMENTS                            1733.143852
# MINIMUM_PAYMENTS                     864.206542
# PRC_FULL_PAYMENT                       0.153715
# TENURE                                11.517318
# dtype: float64

# %% [markdown]
# Deskripsi dari hasil central tendency (central tendency values) untuk setiap variabel pada dataset:
#
# BALANCE: Rata-rata saldo adalah sekitar 1564.47.
# BALANCE_FREQUENCY: Rata-rata frekuensi pembayaran saldo adalah sekitar 0.88.
# PURCHASES: Rata-rata jumlah pembelian adalah sekitar 1003.20.
# ONEOFF_PURCHASES: Rata-rata jumlah pembelian satu kali adalah sekitar 592.44.
# INSTALLMENTS_PURCHASES: Rata-rata jumlah pembelian dengan cicilan adalah sekitar 411.07.
# CASH_ADVANCE: Rata-rata jumlah penarikan tunai adalah sekitar 978.87.
# PURCHASES_FREQUENCY: Rata-rata frekuensi pembelian adalah sekitar 0.49.
# ONEOFF_PURCHASES_FREQUENCY: Rata-rata frekuensi pembelian satu kali adalah sekitar 0.20.
# PURCHASES_INSTALLMENTS_FREQUENCY: Rata-rata frekuensi pembelian dengan cicilan adalah sekitar 0.36.
# CASH_ADVANCE_FREQUENCY: Rata-rata frekuensi penarikan tunai adalah sekitar 0.14.
# CASH_ADVANCE_TRX: Rata-rata jumlah transaksi penarikan tunai adalah sekitar 3.25.
# PURCHASES_TRX: Rata-rata jumlah transaksi pembelian adalah sekitar 14.71.
# CREDIT_LIMIT: Rata-rata batas kredit adalah sekitar 4494.45.
# PAYMENTS: Rata-rata jumlah pembayaran adalah sekitar 1733.14.
# MINIMUM_PAYMENTS: Rata-rata pembayaran minimum adalah sekitar 864.21.
# PRC_FULL_PAYMENT: Rata-rata proporsi pembayaran penuh adalah sekitar 0.15.
# TENURE: Rata-rata durasi kepemilikan akun adalah sekitar 11.52.
#
# Nilai-nilai tersebut merupakan nilai rata-rata dari masing-masing variabel pada dataset. Rata-rata (mean) adalah nilai pusat yang menunjukkan kecenderungan nilai data pada variabel tersebut.

# %% [markdown]
# Calculates the median (middle value) of a numeric column

# %%
median_values = numeric_columns.median()
print("\nMedian (Nilai Tengah) Values:")
print(median_values)
# Out:
# Median (Nilai Tengah) Values:
# BALANCE                              873.385231
# BALANCE_FREQUENCY                      1.000000
# PURCHASES                            361.280000
# ONEOFF_PURCHASES                      38.000000
# INSTALLMENTS_PURCHASES                89.000000
# CASH_ADVANCE                           0.000000
# PURCHASES_FREQUENCY                    0.500000
# ONEOFF_PURCHASES_FREQUENCY             0.083333
# PURCHASES_INSTALLMENTS_FREQUENCY       0.166667
# CASH_ADVANCE_FREQUENCY                 0.000000
# CASH_ADVANCE_TRX                       0.000000
# PURCHASES_TRX                          7.000000
# CREDIT_LIMIT                        3000.000000
# PAYMENTS                             856.901546
# MINIMUM_PAYMENTS                     312.343947
# PRC_FULL_PAYMENT                       0.000000
# TENURE                                12.000000
# dtype: float64

# %% [markdown]
# Deskripsi dari hasil central tendency (central tendency values) berupa nilai median (nilai tengah) untuk setiap variabel pada dataset:
#
# BALANCE: Nilai tengah saldo adalah sekitar 873.39.
# BALANCE_FREQUENCY: Nilai tengah frekuensi pembayaran saldo adalah 1.0.
# PURCHASES: Nilai tengah jumlah pembelian adalah sekitar 361.28.
# ONEOFF_PURCHASES: Nilai tengah jumlah pembelian satu kali adalah 38.0.
# INSTALLMENTS_PURCHASES: Nilai tengah jumlah pembelian dengan cicilan adalah 89.0.
# CASH_ADVANCE: Nilai tengah jumlah penarikan tunai adalah 0.0.
# PURCHASES_FREQUENCY: Nilai tengah frekuensi pembelian adalah 0.5.
# ONEOFF_PURCHASES_FREQUENCY: Nilai tengah frekuensi pembelian satu kali adalah 0.083.
# PURCHASES_INSTALLMENTS_FREQUENCY: Nilai tengah frekuensi pembelian dengan cicilan adalah 0.167.
# CASH_ADVANCE_FREQUENCY: Nilai tengah frekuensi penarikan tunai adalah 0.0.
# CASH_ADVANCE_TRX: Nilai tengah jumlah transaksi penarikan tunai adalah 0.0.
# PURCHASES_TRX: Nilai tengah jumlah transaksi pembelian adalah 7.0.
# CREDIT_LIMIT: Nilai tengah batas kredit adalah 3000.0.
# PAYMENTS: Nilai tengah jumlah pembayaran adalah sekitar 856.90.
# MINIMUM_PAYMENTS: Nilai tengah pembayaran minimum adalah sekitar 312.34.
# PRC_FULL_PAYMENT: Nilai tengah proporsi pembayaran penuh adalah 0.0.
# TENURE: Nilai tengah durasi kepemilikan akun adalah 12.0.
#
# Nilai-nilai tersebut merupakan nilai tengah atau median dari masing-masing variabel pada dataset. Median adalah nilai tengah dalam distribusi data, yang membagi data menjadi dua bagian yang sama besar.

# %% [markdown]
# Calculates the mode (mode) from a numeric column

# %%
mode_values = numeric_columns.mode().iloc[0]
print("\nMode (Modus) Values:")
print(mode_values)
# Out:
# Mode (Modus) Values:
# BALANCE                                0.000000
# BALANCE_FREQUENCY                      1.000000
# PURCHASES                              0.000000
# ONEOFF_PURCHASES                       0.000000
# INSTALLMENTS_PURCHASES                 0.000000
# CASH_ADVANCE                           0.000000
# PURCHASES_FREQUENCY                    1.000000
# ONEOFF_PURCHASES_FREQUENCY             0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY       0.000000
# CASH_ADVANCE_FREQUENCY                 0.000000
# CASH_ADVANCE_TRX                       0.000000
# PURCHASES_TRX                          0.000000
# CREDIT_LIMIT                        3000.000000
# PAYMENTS                               0.000000
# MINIMUM_PAYMENTS                     299.351881
# PRC_FULL_PAYMENT                       0.000000
# TENURE                                12.000000
# Name: 0, dtype: float64

# %% [markdown]
# Deskripsi dari hasil central tendency (central tendency values) berupa nilai modus untuk setiap variabel pada dataset:
#
# BALANCE: Modus (nilai yang paling sering muncul) saldo adalah 0.0.
# BALANCE_FREQUENCY: Modus frekuensi pembayaran saldo adalah 1.0.
# PURCHASES: Modus jumlah pembelian adalah 0.0.
# ONEOFF_PURCHASES: Modus jumlah pembelian satu kali adalah 0.0.
# INSTALLMENTS_PURCHASES: Modus jumlah pembelian dengan cicilan adalah 0.0.
# CASH_ADVANCE: Modus jumlah penarikan tunai adalah 0.0.
# PURCHASES_FREQUENCY: Modus frekuensi pembelian adalah 1.0.
# ONEOFF_PURCHASES_FREQUENCY: Modus frekuensi pembelian satu kali adalah 0.0.
# PURCHASES_INSTALLMENTS_FREQUENCY: Modus frekuensi pembelian dengan cicilan adalah 0.0.
# CASH_ADVANCE_FREQUENCY: Modus frekuensi penarikan tunai adalah 0.0.
# CASH_ADVANCE_TRX: Modus jumlah transaksi penarikan tunai adalah 0.0.
# PURCHASES_TRX: Modus jumlah transaksi pembelian adalah 0.0.
# CREDIT_LIMIT: Modus batas kredit adalah 3000.0.
# PAYMENTS: Modus jumlah pembayaran adalah 0.0.
# MINIMUM_PAYMENTS: Modus pembayaran minimum adalah sekitar 299.35.
# PRC_FULL_PAYMENT: Modus proporsi pembayaran penuh adalah 0.0.
# TENURE: Modus durasi kepemilikan akun adalah 12.0.
#
# Nilai-nilai tersebut merupakan nilai modus atau nilai yang paling sering muncul dari masing-masing variabel pada dataset. Modus digunakan untuk mengidentifikasi nilai yang paling umum atau dominan dalam distribusi data. Modus berguna dalam memahami pola atau kecenderungan tertentu dalam dataset.

# %% [markdown]
# # Variability

# %% [markdown]
# Calculates the range of numeric columns

# %%
range_values = data.select_dtypes(include='number').max() - data.select_dtypes(include='number').min()
print("Range Values:")
print(range_values)
# Out:
# Range Values:
# BALANCE                             19043.138560
# BALANCE_FREQUENCY                       1.000000
# PURCHASES                           49039.570000
# ONEOFF_PURCHASES                    40761.250000
# INSTALLMENTS_PURCHASES              22500.000000
# CASH_ADVANCE                        47137.211760
# PURCHASES_FREQUENCY                     1.000000
# ONEOFF_PURCHASES_FREQUENCY              1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY        1.000000
# CASH_ADVANCE_FREQUENCY                  1.500000
# CASH_ADVANCE_TRX                      123.000000
# PURCHASES_TRX                         358.000000
# CREDIT_LIMIT                        29950.000000
# PAYMENTS                            50721.483360
# MINIMUM_PAYMENTS                    76406.188357
# PRC_FULL_PAYMENT                        1.000000
# TENURE                                  6.000000
# dtype: float64

# %% [markdown]
# Deskripsi dari hasil range (selisih nilai maksimum dan minimum) untuk setiap kolom dalam dataset CC GENERAL.csv:
#
# BALANCE: Rentang nilai antara 0 hingga 19043.138560.
# BALANCE_FREQUENCY: Rentang nilai antara 0 hingga 1.
# PURCHASES: Rentang nilai antara 0 hingga 49039.57.
# ONEOFF_PURCHASES: Rentang nilai antara 0 hingga 40761.25.
# INSTALLMENTS_PURCHASES: Rentang nilai antara 0 hingga 22500.
# CASH_ADVANCE: Rentang nilai antara 0 hingga 47137.21176.
# PURCHASES_FREQUENCY: Rentang nilai antara 0 hingga 1.
# ONEOFF_PURCHASES_FREQUENCY: Rentang nilai antara 0 hingga 1.
# PURCHASES_INSTALLMENTS_FREQUENCY: Rentang nilai antara 0 hingga 1.
# CASH_ADVANCE_FREQUENCY: Rentang nilai antara 0 hingga 1.5.
# CASH_ADVANCE_TRX: Rentang nilai antara 0 hingga 123.
# PURCHASES_TRX: Rentang nilai antara 0 hingga 358.
# CREDIT_LIMIT: Rentang nilai antara 0 hingga 29950.
# PAYMENTS: Rentang nilai antara 0 hingga 50721.48336.
# MINIMUM_PAYMENTS: Rentang nilai antara 0 hingga 76406.188357.
# PRC_FULL_PAYMENT: Rentang nilai antara 0 hingga 1.
# TENURE: Rentang nilai antara 0 hingga 6.

# %% [markdown]
# Calculates the variance of numeric columns

# %%
variance_values = data.select_dtypes(include='number').var()
print("\nVariance Values:")
print(variance_values)
# Out:
# Variance Values:
# BALANCE                             4.332775e+06
# BALANCE_FREQUENCY                   5.612351e-02
# PURCHASES                           4.565208e+06
# ONEOFF_PURCHASES                    2.755228e+06
# INSTALLMENTS_PURCHASES              8.178274e+05
# CASH_ADVANCE                        4.398096e+06
# PURCHASES_FREQUENCY                 1.610985e-01
# ONEOFF_PURCHASES_FREQUENCY          8.900441e-02
# PURCHASES_INSTALLMENTS_FREQUENCY    1.579647e-01
# CASH_ADVANCE_FREQUENCY              4.004857e-02
# CASH_ADVANCE_TRX                    4.657580e+01
# PURCHASES_TRX                       6.179027e+02
# CREDIT_LIMIT                        1.324098e+07
# PAYMENTS                            8.381394e+06
# MINIMUM_PAYMENTS                    5.628503e+06
# PRC_FULL_PAYMENT                    8.555578e-02
# TENURE                              1.791129e+00
# dtype: float64

# %% [markdown]
# Deskripsi dari hasil variabilitas (variasi) untuk setiap kolom:
#
# BALANCE: Variabilitas pada kolom ini adalah sebesar 4.332775e+06.
# BALANCE_FREQUENCY: Variabilitas pada kolom ini adalah sebesar 5.612351e-02.
# PURCHASES: Variabilitas pada kolom ini adalah sebesar 4.565208e+06.
# ONEOFF_PURCHASES: Variabilitas pada kolom ini adalah sebesar 2.755228e+06.
# INSTALLMENTS_PURCHASES: Variabilitas pada kolom ini adalah sebesar 8.178274e+05.
# CASH_ADVANCE: Variabilitas pada kolom ini adalah sebesar 4.398096e+06.
# PURCHASES_FREQUENCY: Variabilitas pada kolom ini adalah sebesar 1.610985e-01.
# ONEOFF_PURCHASES_FREQUENCY: Variabilitas pada kolom ini adalah sebesar 8.900441e-02.
# PURCHASES_INSTALLMENTS_FREQUENCY: Variabilitas pada kolom ini adalah sebesar 1.579647e-01.
# CASH_ADVANCE_FREQUENCY: Variabilitas pada kolom ini adalah sebesar 4.004857e-02.
# CASH_ADVANCE_TRX: Variabilitas pada kolom ini adalah sebesar 4.657580e+01.
# PURCHASES_TRX: Variabilitas pada kolom ini adalah sebesar 6.179027e+02.
# CREDIT_LIMIT: Variabilitas pada kolom ini adalah sebesar 1.324098e+07.
# PAYMENTS: Variabilitas pada kolom ini adalah sebesar 8.381394e+06.
# MINIMUM_PAYMENTS: Variabilitas pada kolom ini adalah sebesar 5.628503e+06.
# PRC_FULL_PAYMENT: Variabilitas pada kolom ini adalah sebesar 8.555578e-02.
# TENURE: Variabilitas pada kolom ini adalah sebesar 1.791129e+00.
#
# Variabilitas mengukur sejauh mana data tersebar atau beragam dalam suatu kolom.

# %% [markdown]
# Calculates the standard deviation of numeric fields

# %%
std_deviation_values = data.select_dtypes(include='number').std()
print("\nStandard Deviation Values:")
print(std_deviation_values)
# Out:
# Standard Deviation Values:
# BALANCE                             2081.531879
# BALANCE_FREQUENCY                      0.236904
# PURCHASES                           2136.634782
# ONEOFF_PURCHASES                    1659.887917
# INSTALLMENTS_PURCHASES               904.338115
# CASH_ADVANCE                        2097.163877
# PURCHASES_FREQUENCY                    0.401371
# ONEOFF_PURCHASES_FREQUENCY             0.298336
# PURCHASES_INSTALLMENTS_FREQUENCY       0.397448
# CASH_ADVANCE_FREQUENCY                 0.200121
# CASH_ADVANCE_TRX                       6.824647
# PURCHASES_TRX                         24.857649
# CREDIT_LIMIT                        3638.815725
# PAYMENTS                            2895.063757
# MINIMUM_PAYMENTS                    2372.446607
# PRC_FULL_PAYMENT                       0.292499
# TENURE                                 1.338331
# dtype: float64

# %%
Deskripsi dari hasil standar deviasi (deviasi standar) untuk setiap kolom:

BALANCE: Standar deviasi pada kolom ini adalah sebesar 2081.531879.
BALANCE_FREQUENCY: Standar deviasi pada kolom ini adalah sebesar 0.236904.
PURCHASES: Standar deviasi pada kolom ini adalah sebesar 2136.634782.
ONEOFF_PURCHASES: Standar deviasi pada kolom ini adalah sebesar 1659.887917.
INSTALLMENTS_PURCHASES: Standar deviasi pada kolom ini adalah sebesar 904.338115.
CASH_ADVANCE: Standar deviasi pada kolom ini adalah sebesar 2097.163877.
PURCHASES_FREQUENCY: Standar deviasi pada kolom ini adalah sebesar 0.401371.
ONEOFF_PURCHASES_FREQUENCY: Standar deviasi pada kolom ini adalah sebesar 0.298336.
PURCHASES_INSTALLMENTS_FREQUENCY: Standar deviasi pada kolom ini adalah sebesar 0.397448.
CASH_ADVANCE_FREQUENCY: Standar deviasi pada kolom ini adalah sebesar 0.200121.
CASH_ADVANCE_TRX: Standar deviasi pada kolom ini adalah sebesar 6.824647.
PURCHASES_TRX: Standar deviasi pada kolom ini adalah sebesar 24.857649.
CREDIT_LIMIT: Standar deviasi pada kolom ini adalah sebesar 3638.815725.
PAYMENTS: Standar deviasi pada kolom ini adalah sebesar 2895.063757.
MINIMUM_PAYMENTS: Standar deviasi pada kolom ini adalah sebesar 2372.446607.
PRC_FULL_PAYMENT: Standar deviasi pada kolom ini adalah sebesar 0.292499.
TENURE: Standar deviasi pada kolom ini adalah sebesar 1.338331.
    
Standar deviasi mengukur seberapa jauh data tersebar atau beragam dari nilai rata-ratanya.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Import the required libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# Load data

# %%
data = pd.read_csv('CC GENERAL.csv')

# %% [markdown]
# Remove unnecessary columns

# %%
df = df.drop(['CUST_ID'], axis=1)

# %% [markdown]
# Fill in the missing values (if any) with the median value of the column

# %%
df = df.fillna(df.median())

# %% [markdown]
# Encoding categorical variables to be numeric using LabelEncoder

# %%
label_encoder = LabelEncoder()
df['TENURE'] = label_encoder.fit_transform(df['TENURE'])

# %% [markdown]
# Standarisasi fitur numerik menggunakan StandardScaler

# %%
scaler = StandardScaler()
numeric_features = ['BALANCE', 'PURCHASES', 'CASH_ADVANCE', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS']
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %% [markdown]
# Save the processed data

# %%
df.to_csv('preprocessed_CC_GENERAL.csv', index=False)

# %% [markdown]
# # Modelling

# %% [markdown]
# # Visualisasi Data CC GENERAL

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV files
df = pd.read_csv('CC GENERAL.CSV')

# Specify the title, axis labels, and size of the image
title = 'Visualisasi Data CC GENERAL'
x_label = 'X-axis Label'
y_label = 'Y-axis Label'
figure_size = (10, 6)  # Image size (width, height) in inches

# Define colors and labels for each data category
colors = {'Kategori1': 'blue', 'Kategori2': 'green', 'Kategori3': 'red'}

# Create a plot based on the desired column
plt.figure(figsize=figure_size)
for category, color in colors.items():
    category_df = df[df['BALANCE'] == category]
    plt.scatter(category_df['CREDIT_LIMIT'], category_df['BALANCE'], c=color, label=category)

# Add a title, axis labels and legend
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.legend()

# Add annotations for multiple data points
annotations = [(x, y, CREDIT_LIMIT) for x, y, label in zip(df['CREDIT_LIMIT'], df['BALANCE'], df['CUST_ID']) if label == 'Anotasi']
for x, y, label in annotations:
    plt.annotate(label, (x, y), textcoords="offset points", xytext=(0,10), ha='center')

# %% [markdown]
# # Implementasi Clustering dengan Scikit-Learn

# %% [markdown]
# import the required libraries

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv('CC GENERAL.csv')

# %% [markdown]
# Omitted the 'CUST_ID' column as it is irrelevant for clustering

# %%
df = df.drop('CUST_ID', axis=1)

# %% [markdown]
# Fill in the missing values with the median value

# %%
df = df.fillna(df.median())

# %% [markdown]
# Standarisasi data

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %% [markdown]
# Determining the optimal number of clusters using the elbow method

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(df_scaled)
    wcss.append(kmeans.inertia_)

# %% [markdown]
# Plot elbow curve

# %%
plt.plot(range(1, 11), wcss)
plt.title('Elbow Curve')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Using the optimal number of clusters

# %%
n_clusters = 4
kmeans = KMeans(n_clusters=n_clusters, init='k-means++', random_state=42)
kmeans.fit(df_scaled)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# Adding the cluster label column to the dataset

# %%
df['Cluster'] = kmeans.labels_

# %% [markdown]
# Displays clustering results

# %%
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)
cluster_labels = [f'Cluster {i+1}' for i in range(n_clusters)]

for i, label in enumerate(cluster_labels):
    print(f'{label}:')
    print(cluster_centers[i])
    print()
# Out:
# Cluster 1:
# [8.94907458e+02 9.34734266e-01 1.23617893e+03 5.93974874e+02
#  6.42478274e+02 2.10570626e+02 8.85165249e-01 2.97070478e-01
#  7.11842047e-01 4.25734663e-02 7.90020790e-01 2.20917731e+01
#  4.21320768e+03 1.33219421e+03 6.39677258e+02 2.69257501e-01
#  1.15945946e+01]
#
# Cluster 2:
# [4.60244966e+03 9.68388788e-01 5.01862982e+02 3.20188797e+02
#  1.81759123e+02 4.52150958e+03 2.87831962e-01 1.38910650e-01
#  1.85670837e-01 4.84791774e-01 1.42949039e+01 7.66583124e+00
#  7.54616086e+03 3.48405422e+03 2.00367446e+03 3.48883083e-02
#  1.13868003e+01]
#
# Cluster 3:
# [1.01265833e+03 7.89924064e-01 2.70041785e+02 2.09937299e+02
#  6.03714408e+01 5.96509903e+02 1.70144908e-01 8.63013025e-02
#  8.05575482e-02 1.14845967e-01 2.12547146e+00 2.90319336e+00
#  3.27864052e+03 9.74260054e+02 5.53900449e+02 7.79812560e-02
#  1.14465678e+01]
#
# Cluster 4:
# [3.55115376e+03 9.86878575e-01 7.68162010e+03 5.09587883e+03
#  2.58720826e+03 6.53638891e+02 9.46417738e-01 7.39030910e-01
# ...

# %% [markdown]
# Displays the amount of data in each cluster

# %%
print(df['Cluster'].value_counts())
# Out:
# 2    3977
# 0    3367
# 1    1197
# 3     409
# Name: Cluster, dtype: int64

# %% [markdown]
# # Analysis

# %% [markdown]
# Deskripsi model Clustering:
#
# Model clustering adalah metode analisis data yang digunakan untuk mengelompokkan objek atau data menjadi kelompok-kelompok yang serupa berdasarkan kesamaan karakteristik atau pola yang dimiliki. Tujuan utama dari model clustering adalah mengidentifikasi struktur yang tersembunyi dalam data tanpa adanya label kelas atau informasi sebelumnya.

# %% [markdown]
# Berdasarkan model clustering yang telah dibuat menggunakan dataset "CC GENERAL.CSV", berikut adalah analisis informasi yang dapat diperoleh:
#
# Segmentasi Pelanggan: Model clustering telah mengelompokkan data pelanggan ke dalam beberapa cluster berdasarkan fitur-fitur yang ada dalam dataset. Setiap cluster mewakili kelompok pelanggan dengan karakteristik yang serupa. Informasi ini dapat digunakan untuk melakukan segmentasi pelanggan yang memungkinkan untuk menyesuaikan strategi pemasaran dan layanan yang lebih spesifik untuk setiap kelompok.
#
# Pola Pengelompokan: Melalui analisis clustering, dapat ditemukan pola pengelompokan yang mencerminkan kecenderungan dan hubungan antara fitur-fitur dalam dataset. Misalnya, cluster-cluster yang terbentuk dapat mencerminkan perbedaan tingkat pengeluaran, kebiasaan pembayaran, atau aktivitas kartu kredit.
#
# Karakteristik Cluster: Dalam setiap cluster, terdapat karakteristik yang membedakan dari cluster lainnya. Dengan menganalisis fitur-fitur yang memiliki perbedaan signifikan antara cluster, kita dapat mengidentifikasi fitur-fitur yang paling mempengaruhi pembentukan cluster.
#
# Anomali atau Outlier: Melalui visualisasi hasil clustering, kita dapat mengidentifikasi titik-titik data yang tidak tergolong dalam salah satu cluster atau menjadi outlier. Identifikasi anomali ini dapat memberikan wawasan tambahan tentang pelanggan yang memiliki perilaku atau karakteristik yang unik atau tidak biasa. Hal ini dapat berguna dalam mengidentifikasi pelanggan potensial yang membutuhkan perhatian khusus atau tindakan lebih lanjut.

# %% [markdown]
# Kesimpulan dari model Cluterring:
#
#
# terdapat 4 klaster yang dihasilkan. Setiap klaster memiliki representasi berikut:
#
# Klaster 1: Klaster ini memiliki nilai rata-rata yang relatif rendah untuk sebagian besar atribut. Pengguna dalam klaster ini cenderung memiliki saldo kartu kredit yang rendah, frekuensi pembelian yang rendah, dan menggunakan fasilitas cash advance dengan frekuensi yang rendah. Mereka juga cenderung memiliki kredit limit yang rendah dan melakukan pembayaran minimum yang lebih rendah.
#
# Klaster 2: Klaster ini memiliki nilai rata-rata yang sedang untuk atribut saldo kartu kredit, frekuensi pembelian, dan penggunaan fasilitas cash advance. Pengguna dalam klaster ini memiliki kredit limit yang sedang dan cenderung melakukan pembayaran yang lebih tinggi daripada klaster lainnya.
#
# Klaster 3: Pengguna dalam klaster ini memiliki saldo kartu kredit, frekuensi pembelian, dan penggunaan fasilitas cash advance yang rendah. Mereka juga cenderung memiliki kredit limit yang rendah dan melakukan pembayaran minimum yang rendah.
#
# Klaster 4: Pengguna dalam klaster ini memiliki saldo kartu kredit yang tinggi, frekuensi pembelian yang tinggi, dan menggunakan fasilitas cash advance dengan frekuensi yang tinggi. Mereka juga cenderung memiliki kredit limit yang tinggi dan melakukan pembayaran yang lebih tinggi.
#
# Kesimpulan dari hasil klastering tersebut adalah terdapat perbedaan yang signifikan antara setiap klaster dalam hal pola penggunaan kartu kredit. Klaster 1 dan 3 cenderung memiliki penggunaan kartu kredit yang lebih rendah, sedangkan Klaster 2 dan 4 cenderung memiliki penggunaan kartu kredit yang lebih tinggi. Klaster 4 memiliki saldo kartu kredit yang lebih tinggi, frekuensi pembelian yang tinggi, dan lebih sering menggunakan fasilitas cash advance. Klaster 2 memiliki saldo kartu kredit yang tinggi namun frekuensi pembelian yang rendah. Klaster 1 dan 3 memiliki saldo kartu kredit dan penggunaan kartu kredit yang lebih rendah secara keseluruhan.
